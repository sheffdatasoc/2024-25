# %% [markdown]
# #EDA Sandbox
#
# download this data and import it https://github.com/datasciencedojo/datasets/blob/master/titanic.csv
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Refer to the guides
# ### [Pandas](https://uosdss.wordpress.com/2024/10/21/pandas-guide/)
# ### [matplotlib](https://uosdss.wordpress.com/2024/10/29/matplotlib/)
# ### [Seaborn](https://uosdss.wordpress.com/2024/10/30/seaborn/)
#
# ---

# %% [markdown]
# # Beginner Level

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Challenge 1
# 1. Load Data
# 2. Summarize Your Data
# 3. how many passengers are there?
#
#
# hints:
#
# https://uosdss.wordpress.com/2024/10/21/pandas-guide/#read-csv
#
# https://uosdss.wordpress.com/2024/10/21/pandas-guide/#df-head-n
#
# https://uosdss.wordpress.com/2024/10/21/pandas-guide/#df-info
#
# https://uosdss.wordpress.com/2024/10/21/pandas-guide/#describe

# %% [markdown]
# #Challange 2
# Separate the data into numerical and categorical lists
#
# 1. numerical_columns =[]
# 2. categorical_columns[]
# hints:
#
# https://www.w3schools.com/python/pandas/ref_df_select_dtypes.asp
#
# more:
# https://uosdss.wordpress.com/2024/10/21/pandas-guide/#selecting-rows:~:text=concept%20from%20lists.-,Selecting%20rows%20with%20condition,-df%5Bdf%5B%27release_year
#
# https://uosdss.wordpress.com/2024/10/21/pandas-guide/#dtype-s:~:text=indexes%20%2C%20column%20indexes%5D-,.dtype/s%3A,-This%20attribute%20returns

# %% [markdown]
# # Intermediate Level

# %% [markdown]
# #Challenge 3
# - Find the percentage of men who survived
# - Did more women or men survive?
# - How old was the youngest passenger?

# %% [markdown]
# # Challenge 4
# Visualizing categorical columns (sex , survived)
#
# Need help:
#
# https://www.codecademy.com/learn/dscp-summary-statistics/modules/dacp-visualizing-categorical-data/cheatsheet
#
#
# https://seaborn.pydata.org/tutorial/categorical.html
#
# https://www.w3schools.com/python/matplotlib_pie_charts.asp

# %% [markdown]
# # Advance

# %% [markdown]
# #Challenge 5
#
# Via visualisation or mathematical calculation find the following:
#
#
# 1.      Find out if the age column is normally distributed.
# 2.      Find out if the fates column is normally distributed.
#
#
# hint:
# https://www.statology.org/normality-test-python/

# %% [markdown]
# # Challenge 6
#
# 1. Visualise the correlation between all columns using sub graphs heat map
# Find if there is correlation between surviving and any other column
#
# hint:
#
# https://www.geeksforgeeks.org/how-to-create-a-seaborn-correlation-heatmap-in-python/
#
#
# https://www.w3schools.com/python/pandas/pandas_correlations.asp
