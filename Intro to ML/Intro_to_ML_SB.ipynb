# %% [markdown]
# # **Introduction: Intro to ML Sandbox**
# Welcome to **The Sandbox, hosted by the Data Science Society at the University of Sheffield** ! 🎓
#
# In this hands-on session, we’ll introduce Machine Learning concepts a big area of Data Science. Using the famous **Iris** and **Housing** Datasets, you’ll get exposed to how to identify and address real-world data in a beginner-friendly environment. This session is designed to help you build confidence in working withhigh level topics.

# %% [markdown]
# # What Is Machine Learning?
#
#
# In this session, we will focus on:
#
# - Explaning Train Test Splitting
# - Using different Classifier Models
# - Diferentiating between Supervised and Unsupervised Learning
# - Making a Prediction with Regression
# - Explain the benefits of Cross-Validation

# %% [markdown]
# # Why these Datasets?
# Both datasets are widely-used and beginner-friendly resources in the data science community. Although both can be used for anything we will be using:
#
# 1.   Iris (For Classification)
# 2.   Housing (For Regression)

# %% [markdown]
# ##Let's get started ❗

# %% [markdown]
# Download and import our preprocessed datasets: https://github.com/sheffdatasoc/2024-2025/tree/main/Sandbox%20Sessions/Intro%20to%20ML

# %% [markdown]
# SET UP: Load the **Encoded_Iris** and **Encoded_Housing** Datasets

# %% [markdown]
# ![Screenshot 2024-11-14 at 17.20.49.png](data:image/png;base64,...)

# %% [markdown]
# # Challenge 1:
# ##Spliting Data for Iris Dataset
#
# **Scenario:** Imagine you're a scientist working on the Iris dataset. You magically have an already Standardised and Encoded Dataset
#
# **Your Task:**
# - Split the data into features (X) and target (y)
# - Split the data into training and testing

# %%
#Import the neccesary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# Load the dataset


# Split the data into features and target label


# Split the data into training and testing sets

# %% [markdown]
# # Challenge 2: Supervised Classification
#
# **Your Task:**
#
#
# * Using a Decision Tree Algorithm, fit your training data (This is now a Model)
# * Make a prediction on the test data
# * Evaluate how the algorithm performs on your data
# * Extra: Use another Supervised model (Maybe KMeans?)

# %%
#Initialize the Decision Tree model

#Fit the model on the training data

#Make predictions on the test set

#Evaluate the model's performance

#EXTRA Visualise the Accuracy

# %% [markdown]
# ###Try changing the test_size and see how that affects your model performance...

# %% [markdown]
# For more on Decision Tree Classification
#
# ---
#
# Refer to: https://scikit-learn.org/1.5/modules/tree.html#classification

# %% [markdown]
# # Challenge 3: Unsupervised Classification
#
# **Observation:** While in supervised learning you would typically fit the model using the training data and then evaluate it on the test data, KMeans clustering is unsupervised. It only uses the features (X) to identify patterns or clusters in the data.
#
# **Your Task:**
#
#
# * Initialise the K-Means Algorithm.
# * Predict the cluster labels
# * Evaluate how the algorithm performs (Using KMeans Metrics)

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
#Initialize the KMeans model

#Fit KMeans on the entire dataset

# Get the predicted cluster labels

#Calculate the silhouette score for clustering evaluation

#EXTRA Visualise the Clusters

# %% [markdown]
# For more on K Means Clustering
#
# ---
#
# Refer to: https://scikit-learn.org/1.5/modules/clustering.html

# %% [markdown]
# # Challenge 4:
# ##Spliting Data for Housing Dataset
#
# **Scenario:** Imagine you're a scientist working on the Housing dataset. You magically have an already Standardised and Encoded Dataset
#
# **Your Task:**
# - Split the data into features (X) and target (y)
# - Split the data into training and testing

# %%
#import the necessary libraries
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# Load the dataset


# Split the data into features and target label


# Split the data into training and testing sets

# %% [markdown]
# # Challenge 5: Regression
#
# **Your Task:**
#
# * Using a Linear Regression Algorithm, fit your training data (This is now a Model)
# * Make a prediction on the test data
# * Evaluate how the algorithm performs on your data
# * Extra: Use another Supervised model (Maybe Non_Linear examples? Logisitic?)

# %%
#Initialise the Linear Regression model


#Fit the model on the training data


# Make predictions on the test set


# Evaluate the model's performance (Using the Regression Metrics)


#EXTRA Visualise the Accuracy

# %% [markdown]
# For more on Linear Models
#
# ---
#
# Refer to: https://scikit-learn.org/1.5/modules/linear_model.html

# %% [markdown]
# # Challenge 6: Cross-Validation
# **Scenario:** So far you have been a noob and only testing on one set of data.. Time to change that so your model is way better
#
# **Your Task:**
# * Set up 10 stratified KFolds
# * Fit your Training and Testing data into the Cross Validation loop (This can be your Iris or Housing Data)
# * Output a list of all the Fold Accuracies (to 2 decimal places)
# * Print the Mean Accuracy and it's Standard Deviation

# %%
from sklearn.model_selection import StratifiedKFold

# Fix Random seed for Reproducibility

# Load Iris or Housing dataset, and split into Features and Target (As always)

# Define 10-fold cross-validation (KFold)

# List to hold accuracy scores from each fold

# Cross-Validation Loop
for train, test in kfold.split(X, Y):
    # Initialise the Model (random_state=seed)

    # Fit the model on the training data

    # Predict on the test data

    # Evaluate accuracy of the model

    # Append the accuracy to the list of scores

    # Print the accuracy for this fold (For 2 decimal places use ':.2f')

#Calculate and print the mean and standard deviation of accuracy scores
# Out:
#   File "<ipython-input-1-f5d6794f01d1>", line 25
#     # Calculate and print the mean and standard deviation of accuracy scores
#                                                                             ^
# SyntaxError: incomplete input

# %% [markdown]
# For more on Cross Validation
#
# ---
#
# Refer to: https://scikit-learn.org/1.5/modules/cross_validation.html

# %% [markdown]
# #THAT'S THE END FOR NOW :)
# #THANK YOU!
